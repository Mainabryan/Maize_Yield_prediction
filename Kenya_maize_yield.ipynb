# %% [markdown]
# <a href="https://colab.research.google.com/github/Mainabryan/Maize_Yield_prediction/blob/main/Kenya_maize_yield.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import the required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split

# %% [markdown]
# #Load the datset

# %%
data =pd.read_csv('/content/Kenya_Maize_Yield_Dataset.csv')

# %% [markdown]
# ##Exploratory Data Analysis

# %%
data.head()
# Out:
#         Region  County        SubCounty  Soil_Quality  Avg_Rainfall_mm  \
# 0  Rift Valley  Nakuru  Nakuru Sub-East             2       649.671415
# 1      Eastern   Kitui  Kitui Sub-North             4       701.051528
# 2      Eastern    Embu   Embu Sub-South             3       427.508217
# 3      Western   Busia   Busia Sub-West             2       386.037934
# 4      Eastern    Embu    Embu Sub-East             2       547.487715
#
#    Avg_Temperature_C  Altitude_meters  Fertilizer_Usage_kg_per_acre  \
# 0          22.723471             2130                     57.107913
# 1          21.838244             1276                     42.122453
# 2          21.875425             2082                     42.022739
# 3          21.741050             2267                     58.965807
# 4          26.825543             2297                     40.996192
#
#   Fertilizer_Type   Seed_Type Farming_Method Pest_Attack_Level  \
# ...

# %%
data.tail()
# Out:
#           Region   County         SubCounty  Soil_Quality  Avg_Rainfall_mm  \
# 495       Nyanza   Kisumu  Kisumu Sub-South             5       664.912014
# 496       Nyanza   Kisumu  Kisumu Sub-South             1       533.577582
# 497       Nyanza    Siaya   Siaya Sub-North             3       602.780292
# 498  Rift Valley  Baringo  Baringo Sub-East             4       684.901091
# 499       Nyanza    Siaya   Siaya Sub-North             5       616.666169
#
#      Avg_Temperature_C  Altitude_meters  Fertilizer_Usage_kg_per_acre  \
# 495          26.885336             1976                     42.739145
# 496          24.763199             1795                     37.697347
# 497          22.849241             1922                     60.519385
# 498          22.789526             2273                     53.964467
# 499          24.132172             1463                     60.485204
#
#     Fertilizer_Type   Seed_Type Farming_Method Pest_Attack_Level  \
# ...

# %%
data.describe()
# Out:
#        Soil_Quality  Avg_Rainfall_mm  Avg_Temperature_C  Altitude_meters  \
# count    500.000000       500.000000         500.000000       500.000000
# mean       2.890000       601.113747          22.967695      1746.092000
# std        1.380475       102.910990           1.974223       437.423477
# min        1.000000       305.961137          17.302915      1002.000000
# 25%        2.000000       533.458816          21.659263      1362.000000
# 50%        3.000000       605.459679          22.998449      1749.000000
# 75%        4.000000       673.123311          24.277570      2125.500000
# max        5.000000       937.229625          29.122190      2497.000000
#
#        Fertilizer_Usage_kg_per_acre  Prev_Season_Yield  \
# count                    500.000000         500.000000
# mean                      51.129805           2.517535
# std                       15.227721           0.499830
# min                        4.707318           0.760915
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Region                            500 non-null    object
#  1   County                            500 non-null    object
#  2   SubCounty                         500 non-null    object
#  3   Soil_Quality                      500 non-null    int64
#  4   Avg_Rainfall_mm                   500 non-null    float64
#  5   Avg_Temperature_C                 500 non-null    float64
#  6   Altitude_meters                   500 non-null    int64
#  7   Fertilizer_Usage_kg_per_acre      500 non-null    float64
#  8   Fertilizer_Type                   500 non-null    object
#  9   Seed_Type                         500 non-null    object
#  10  Farming_Method                    500 non-null    object
# ...

# %%
data.describe(include='all')
# Out:
#        Region   County         SubCounty  Soil_Quality  Avg_Rainfall_mm  \
# count     500      500               500    500.000000       500.000000
# unique      6       18                72           NaN              NaN
# top     Coast  Bungoma  Kilifi Sub-North           NaN              NaN
# freq      102       40                13           NaN              NaN
# mean      NaN      NaN               NaN      2.890000       601.113747
# std       NaN      NaN               NaN      1.380475       102.910990
# min       NaN      NaN               NaN      1.000000       305.961137
# 25%       NaN      NaN               NaN      2.000000       533.458816
# 50%       NaN      NaN               NaN      3.000000       605.459679
# 75%       NaN      NaN               NaN      4.000000       673.123311
# max       NaN      NaN               NaN      5.000000       937.229625
#
#         Avg_Temperature_C  Altitude_meters  Fertilizer_Usage_kg_per_acre  \
# ...

# %% [markdown]
# #one-hot encoding

# %%
data = pd.get_dummies(data, columns=["Fertilizer_Type", "Seed_Type", "Farming_Method"], drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-20-4217926945.py in <cell line: 0>()
# ----> 1 data = pd.get_dummies(data, columns=["Fertilizer_Type", "Seed_Type", "Farming_Method"], drop_first=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/encoding.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167             raise TypeError("Input must be a list-like for parameter `columns`")
#     168         else:
# --> 169             data_to_encode = data[columns]
#     170
#     171         # validate prefixes and separator to avoid silently dropping cols
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# ...

# %%
sns.histplot(data=data, x='Current_Yield_tonnes_per_hectare')
plt.show()

# %% [markdown]
# correlation

# %%
numeric_data = data.select_dtypes(include=np.number)
display(numeric_data.corr())
# Out:
#                                   Soil_Quality  Avg_Rainfall_mm  \
# Soil_Quality                          1.000000         0.124865
# Avg_Rainfall_mm                       0.124865         1.000000
# Avg_Temperature_C                     0.006399        -0.052775
# Altitude_meters                      -0.076732        -0.060361
# Fertilizer_Usage_kg_per_acre          0.074787        -0.005944
# Prev_Season_Yield                    -0.034172         0.017453
# Farming_Experience_Years             -0.055095         0.036060
# Year                                  0.023574         0.021302
# Current_Yield_tonnes_per_hectare      0.076513         0.151870
#
#                                   Avg_Temperature_C  Altitude_meters  \
# Soil_Quality                               0.006399        -0.076732
# Avg_Rainfall_mm                           -0.052775        -0.060361
# Avg_Temperature_C                          1.000000         0.049191
# ...

# %%
data.columns
# Out:
# Index(['Region', 'County', 'SubCounty', 'Soil_Quality', 'Avg_Rainfall_mm',
#        'Avg_Temperature_C', 'Altitude_meters', 'Fertilizer_Usage_kg_per_acre',
#        'Fertilizer_Type', 'Seed_Type', 'Farming_Method', 'Pest_Attack_Level',
#        'Prev_Season_Yield', 'Farming_Experience_Years', 'Planting_Season',
#        'Year', 'Current_Yield_tonnes_per_hectare'],
#       dtype='object')

# %% [markdown]
# ##  Corelation

# %%
numeric_data = data.select_dtypes(include=[np.number])
corr = numeric_data.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# # Boxplots

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Single boxplot for rainfall
sns.boxplot(x=data["Avg_Rainfall_mm"])
plt.title("Boxplot of Rainfall")
plt.show()

# %%
numeric_data = data.select_dtypes(include=['int64', 'float64'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set(style="whitegrid")
num_cols = numeric_data.columns
n_cols = 3
n_rows = -(-len(num_cols) // n_cols)  # Ceiling division

# Create subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, n_rows * 4))
axes = axes.flatten()

# Loop and plot
for i, col in enumerate(num_cols):
    sns.boxplot(data=numeric_data, x=col, ax=axes[i], color='skyblue')
    axes[i].set_title(f'Boxplot of {col}', fontsize=10)
    axes[i].tick_params(axis='x', labelsize=8)

# Remove empty axes
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-21-160633644.py in <cell line: 0>()
# ----> 1 data = pd.get_dummies(data, columns=["Fertilizer_Type", "Seed_Type", "Farming_Method"], drop_first=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/encoding.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167             raise TypeError("Input must be a list-like for parameter `columns`")
#     168         else:
# --> 169             data_to_encode = data[columns]
#     170
#     171         # validate prefixes and separator to avoid silently dropping cols
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# ...
